# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425344 sha256=56fe872cf2990b843634649f69c4e035a49032499c3d05e862aeca0258656c9f
#   Stored in directory: /root/.cache/pip/wheels/41/4e/10/c2cf2467f71c678cfc8a6b9ac9241e5e44a01940da8fbb17fc
# Successfully built pyspark
# ...

# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Spark').getOrCreate()

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1 PARALLELIZE METHOD

# %%
dataRDD = spark.sparkContext.textFile("drive/My Drive/sampleTemp.txt")

# %%
dataRDD.collect()

# %% [markdown]
# Q1) Read a text file and count the number of words in the file using RDD operations.

# %%
DataFlatMap = dataRDD.flatMap(lambda data : data.split(' '))
DataFlatMap.count()
# Out:
# 5784997

# %% [markdown]
# Q2) Write a program to find the word frequency in a given file.

# %%
DataFlatMap.map(lambda data : (data,1)).reduceByKey(lambda a,b:a+b).collect()
# Out:
# [('1816-03-01', 390),
#  ('India', 960548),
#  ('29.74N', 49460),
#  ('73.85E', 6249),
#  ('1816-04-01', 391),
#  ('1816-05-01', 391),
#  ('32.535000000000004', 21),
#  ('1816-07-01', 391),
#  ('30.429000000000002', 18),
#  ('17.236', 30),
#  ('12.092', 4),
#  ('1817-01-01', 391),
#  ('11.604', 3),
#  ('1817-02-01', 391),
#  ('1817-03-01', 391),
#  ('1817-05-01', 391),
#  ('31.196', 31),
#  ('1817-06-01', 391),
#  ('32.414', 58),
#  ('31.445', 76),
#  ('1817-08-01', 391),
#  ('31.309', 12),
#  ('26.747', 57),
#  ('22.897', 45),
#  ('1817-11-01', 391),
#  ('17.992', 18),
#  ('1818-01-01', 391),
#  ('11.628', 5),
#  ('13.652', 30),
#  ('1818-03-01', 390),
#  ('21.34', 14),
#  ('33.049', 18),
#  ('1818-06-01', 391),
#  ('30.841', 39),
#  ('1818-09-01', 391),
#  ('1818-10-01', 391),
#  ('23.205', 52),
#  ('1818-11-01', 391),
#  ('1818-12-01', 391),
#  ('12.640999999999998', 6),
#  ('1819-01-01', 390),
#  ('1819-02-01', 390),
#  ('14.065999999999999', 41),
#  ('19.064', 26),
# ...

# %% [markdown]
# q3) Write a program to convert all words in a file to uppercase.

# %%
#def filter(d):
#if d.isalpha():
#return true
#filter = dataflatmap.filter(lambda data : filter(data))
#filter.map(lambda data : data.upper()).collect()
DataFlatMap.map(lambda data : data.upper()).collect()
# Out:
# ['1816-03-01',
#  '19.934',
#  'ABOHAR',
#  'INDIA',
#  '29.74N',
#  '73.85E',
#  '1816-04-01',
#  '26.641',
#  'ABOHAR',
#  'INDIA',
#  '29.74N',
#  '73.85E',
#  '1816-05-01',
#  '32.535000000000004',
#  'ABOHAR',
#  'INDIA',
#  '29.74N',
#  '73.85E',
#  '1816-06-01',
#  '33.254',
#  'ABOHAR',
#  'INDIA',
#  '29.74N',
#  '73.85E',
#  '1816-07-01',
#  '31.105',
#  'ABOHAR',
#  'INDIA',
#  '29.74N',
#  '73.85E',
#  '1816-08-01',
#  '30.429000000000002',
#  'ABOHAR',
#  'INDIA',
#  '29.74N',
#  '73.85E',
#  '1816-09-01',
#  '27.903',
#  'ABOHAR',
#  'INDIA',
#  '29.74N',
#  '73.85E',
#  '1816-10-01',
#  '22.144000000000002',
#  'ABOHAR',
#  'INDIA',
#  '29.74N',
#  '73.85E',
#  '1816-11-01',
#  '17.236',
#  'ABOHAR',
#  'INDIA',
#  '29.74N',
#  '73.85E',
#  '1816-12-01',
#  '12.092',
#  'ABOHAR',
#  'INDIA',
#  '29.74N',
#  '73.85E',
#  '1817-01-01',
#  '11.604',
#  'ABOHAR',
#  'INDIA',
#  '29.74N',
#  '73.85E',
#  '1817-02-01',
#  '15.65',
#  'ABOHAR',
#  'INDIA',
#  '29.74N',
# ...

# %% [markdown]
# q4) Write a program to convert all words in a file to lowercase.

# %%
DataFlatMap.map(lambda data:data.lower()).collect()
# Out:
# ['1816-03-01',
#  '19.934',
#  'abohar',
#  'india',
#  '29.74n',
#  '73.85e',
#  '1816-04-01',
#  '26.641',
#  'abohar',
#  'india',
#  '29.74n',
#  '73.85e',
#  '1816-05-01',
#  '32.535000000000004',
#  'abohar',
#  'india',
#  '29.74n',
#  '73.85e',
#  '1816-06-01',
#  '33.254',
#  'abohar',
#  'india',
#  '29.74n',
#  '73.85e',
#  '1816-07-01',
#  '31.105',
#  'abohar',
#  'india',
#  '29.74n',
#  '73.85e',
#  '1816-08-01',
#  '30.429000000000002',
#  'abohar',
#  'india',
#  '29.74n',
#  '73.85e',
#  '1816-09-01',
#  '27.903',
#  'abohar',
#  'india',
#  '29.74n',
#  '73.85e',
#  '1816-10-01',
#  '22.144000000000002',
#  'abohar',
#  'india',
#  '29.74n',
#  '73.85e',
#  '1816-11-01',
#  '17.236',
#  'abohar',
#  'india',
#  '29.74n',
#  '73.85e',
#  '1816-12-01',
#  '12.092',
#  'abohar',
#  'india',
#  '29.74n',
#  '73.85e',
#  '1817-01-01',
#  '11.604',
#  'abohar',
#  'india',
#  '29.74n',
#  '73.85e',
#  '1817-02-01',
#  '15.65',
#  'abohar',
#  'india',
#  '29.74n',
# ...

# %% [markdown]
# Q5) Write  a  program  to  capitalize  first  letter  of  each  words  in  file  (use  string capitalize() method).

# %%
DataFlatMap.map(lambda data  : data.capitalize()).collect()
# Out:
# ['1816-03-01',
#  '19.934',
#  'Abohar',
#  'India',
#  '29.74n',
#  '73.85e',
#  '1816-04-01',
#  '26.641',
#  'Abohar',
#  'India',
#  '29.74n',
#  '73.85e',
#  '1816-05-01',
#  '32.535000000000004',
#  'Abohar',
#  'India',
#  '29.74n',
#  '73.85e',
#  '1816-06-01',
#  '33.254',
#  'Abohar',
#  'India',
#  '29.74n',
#  '73.85e',
#  '1816-07-01',
#  '31.105',
#  'Abohar',
#  'India',
#  '29.74n',
#  '73.85e',
#  '1816-08-01',
#  '30.429000000000002',
#  'Abohar',
#  'India',
#  '29.74n',
#  '73.85e',
#  '1816-09-01',
#  '27.903',
#  'Abohar',
#  'India',
#  '29.74n',
#  '73.85e',
#  '1816-10-01',
#  '22.144000000000002',
#  'Abohar',
#  'India',
#  '29.74n',
#  '73.85e',
#  '1816-11-01',
#  '17.236',
#  'Abohar',
#  'India',
#  '29.74n',
#  '73.85e',
#  '1816-12-01',
#  '12.092',
#  'Abohar',
#  'India',
#  '29.74n',
#  '73.85e',
#  '1817-01-01',
#  '11.604',
#  'Abohar',
#  'India',
#  '29.74n',
#  '73.85e',
#  '1817-02-01',
#  '15.65',
#  'Abohar',
#  'India',
#  '29.74n',
# ...

# %% [markdown]
# Q6) Find the number of occurrence of a word in a given file.

# %%
DataFlatMap.map(lambda data : (data,1)).reduceByKey(lambda a,b:a+b).collect()
# Out:
# [('1816-03-01', 390),
#  ('India', 960548),
#  ('29.74N', 49460),
#  ('73.85E', 6249),
#  ('1816-04-01', 391),
#  ('1816-05-01', 391),
#  ('32.535000000000004', 21),
#  ('1816-07-01', 391),
#  ('30.429000000000002', 18),
#  ('17.236', 30),
#  ('12.092', 4),
#  ('1817-01-01', 391),
#  ('11.604', 3),
#  ('1817-02-01', 391),
#  ('1817-03-01', 391),
#  ('1817-05-01', 391),
#  ('31.196', 31),
#  ('1817-06-01', 391),
#  ('32.414', 58),
#  ('31.445', 76),
#  ('1817-08-01', 391),
#  ('31.309', 12),
#  ('26.747', 57),
#  ('22.897', 45),
#  ('1817-11-01', 391),
#  ('17.992', 18),
#  ('1818-01-01', 391),
#  ('11.628', 5),
#  ('13.652', 30),
#  ('1818-03-01', 390),
#  ('21.34', 14),
#  ('33.049', 18),
#  ('1818-06-01', 391),
#  ('30.841', 39),
#  ('1818-09-01', 391),
#  ('1818-10-01', 391),
#  ('23.205', 52),
#  ('1818-11-01', 391),
#  ('1818-12-01', 391),
#  ('12.640999999999998', 6),
#  ('1819-01-01', 390),
#  ('1819-02-01', 390),
#  ('14.065999999999999', 41),
#  ('19.064', 26),
# ...

# %% [markdown]
# Select only the sentences containing given word from a text file.

# %%
def check(data):
  if 'Rewa' in data:
    return True

dataRDD.filter(lambda data : check(data)==True).collect()
# Out:
# ['1796-01-01 16.186 Rewa India 24.92N 81.58E',
#  '1796-02-01 18.908 Rewa India 24.92N 81.58E',
#  '1796-03-01 23.274 Rewa India 24.92N 81.58E',
#  '1796-04-01 30.173 Rewa India 24.92N 81.58E',
#  '1796-05-01 34.392 Rewa India 24.92N 81.58E',
#  '1796-06-01 33.427 Rewa India 24.92N 81.58E',
#  '1796-07-01 29.616 Rewa India 24.92N 81.58E',
#  '1796-08-01 28.752 Rewa India 24.92N 81.58E',
#  '1796-09-01 28.162 Rewa India 24.92N 81.58E',
#  '1796-10-01 25.763 Rewa India 24.92N 81.58E',
#  '1796-11-01 20.546 Rewa India 24.92N 81.58E',
#  '1796-12-01 14.640999999999998 Rewa India 24.92N 81.58E',
#  '1797-03-01 23.818 Rewa India 24.92N 81.58E',
#  '1797-04-01 29.371 Rewa India 24.92N 81.58E',
#  '1797-05-01 33.633 Rewa India 24.92N 81.58E',
#  '1797-06-01 33.91 Rewa India 24.92N 81.58E',
#  '1797-07-01 29.611 Rewa India 24.92N 81.58E',
#  '1797-08-01 28.75 Rewa India 24.92N 81.58E',
#  '1797-09-01 28.263 Rewa India 24.92N 81.58E',
#  '1797-10-01 25.378 Rewa India 24.92N 81.58E',
# ...

# %% [markdown]
# Q8)Find the longest length of word from given set of words.

# %%
dataRDD.map(lambda data : (len(data),data)).max()
# Out:
# (67, '2013-08-01 26.160999999999998 Thiruvananthapuram India 8.84N 77.03E')

# %% [markdown]
# Map the Registration numbers to corresponding branch. 58000 series BDA, 57000 series AIML,
# 38000 series VLSI, 39000 series ES, and 47000 series CDC. Given registration number, generate a
# key-value pair of Registration Number and Corresponding Branch.

# %%
def branch(d):
  if '580' in d:
    return 'BDA'
  elif '570' in d:
    return 'AIML'
  elif '380' in d:
    return 'VLSI'
  elif '390' in d:
    return 'ES'
  elif '470' in d:
    return 'CDC'
  else:
    return None
student = spark.sparkContext.textFile("drive/My Drive/register.txt")
student.flatMap(lambda d: d.split(' ')).map(lambda d: (d, branch(d))).collect()
# Out:
# [('231058001', 'BDA'),
#  ('231058003', 'BDA'),
#  ('231058007', 'BDA'),
#  ('231058012', 'BDA'),
#  ('231058021', 'BDA'),
#  ('231058029', 'BDA'),
#  ('231057001', 'AIML'),
#  ('231057004', 'AIML'),
#  ('231038001', 'VLSI'),
#  ('231038034', 'VLSI'),
#  ('231039001', 'ES'),
#  ('231047001', 'CDC')]
